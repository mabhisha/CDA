# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('Chicago_Crimes_2012_to_2017.csv')
print('File Read Succesfully')
# Out:
# File Read Succesfully

# %%
data['Date'] = pd.to_datetime(data['Date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2996\1453708669.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Date'] = pd.to_datetime(data['Date'])

# %%
data.tail()
# Out:
#          Unnamed: 0        ID Case Number                Date  \
# 1456709     6250330  10508679    HZ250507 2016-05-03 23:33:00
# 1456710     6251089  10508680    HZ250491 2016-05-03 23:30:00
# 1456711     6251349  10508681    HZ250479 2016-05-03 00:15:00
# 1456712     6253257  10508690    HZ250370 2016-05-03 21:07:00
# 1456713     6253474  10508692    HZ250517 2016-05-03 23:38:00
#
#                         Block  IUCR     Primary Type              Description  \
# 1456709       026XX W 23RD PL  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456710   073XX S HARVARD AVE  1310  CRIMINAL DAMAGE              TO PROPERTY
# 1456711       024XX W 63RD ST  041A          BATTERY      AGGRAVATED: HANDGUN
# 1456712  082XX S EXCHANGE AVE  0486          BATTERY  DOMESTIC BATTERY SIMPLE
# 1456713       001XX E 75TH ST  5007    OTHER OFFENSE  OTHER WEAPONS VIOLATION
#
#                    Location Description  Arrest  ...  Ward  Community Area  \
# 1456709                       APARTMENT    True  ...  28.0            30.0
# 1456710                       APARTMENT    True  ...  17.0            69.0
# 1456711                        SIDEWALK   False  ...  15.0            66.0
# 1456712                        SIDEWALK   False  ...   7.0            46.0
# 1456713  PARKING LOT/GARAGE(NON.RESID.)    True  ...   6.0            69.0
#
#          FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 1456709       08B     1159105.0     1888300.0  2016  05/10/2016 03:56:50 PM
# 1456710        14     1175230.0     1856183.0  2016  05/10/2016 03:56:50 PM
# 1456711       04B     1161027.0     1862810.0  2016  05/10/2016 03:56:50 PM
# 1456712       08B     1197261.0     1850727.0  2016  05/10/2016 03:56:50 PM
# 1456713        26     1178696.0     1855324.0  2016  05/10/2016 03:56:50 PM
#
#           Latitude  Longitude                       Location
# 1456709  41.849222 -87.691556   (41.849222028, -87.69155551)
# 1456710  41.760744 -87.633335   (41.760743949, -87.63333531)
# 1456711  41.779235 -87.685207  (41.779234743, -87.685207125)
# 1456712  41.745252 -87.552773  (41.745251975, -87.552773464)
# 1456713  41.758309 -87.620658   (41.75830866, -87.620658418)
#
# [5 rows x 23 columns]

# %%
data.index= pd.DatetimeIndex(data.Date)
data.index = pd.to_datetime(data.index)

# %%
data['Primary Type'] = pd.Categorical(data['Primary Type'])
data['Description'] = pd.Categorical(data['Description'])
data['Location Description'] = pd.Categorical(data['Location Description'])

# %%
data['Primary Type']
# Out:
# Date
# 2016-05-03 23:40:00                   BATTERY
# 2016-05-03 21:40:00                   BATTERY
# 2016-05-03 23:31:00    PUBLIC PEACE VIOLATION
# 2016-05-03 22:10:00                   BATTERY
# 2016-05-03 22:00:00                     THEFT
#                                 ...
# 2016-05-03 23:33:00                   BATTERY
# 2016-05-03 23:30:00           CRIMINAL DAMAGE
# 2016-05-03 00:15:00                   BATTERY
# 2016-05-03 21:07:00                   BATTERY
# 2016-05-03 23:38:00             OTHER OFFENSE
# Name: Primary Type, Length: 1456714, dtype: category
# Categories (33, object): ['ARSON', 'ASSAULT', 'BATTERY', 'BURGLARY', ..., 'SEX OFFENSE', 'STALKING', 'THEFT', 'WEAPONS VIOLATION']

# %%
data.tail()
# Out:
#                      Unnamed: 0        ID Case Number                Date  \
# Date
# 2016-05-03 23:33:00     6250330  10508679    HZ250507 2016-05-03 23:33:00
# 2016-05-03 23:30:00     6251089  10508680    HZ250491 2016-05-03 23:30:00
# 2016-05-03 00:15:00     6251349  10508681    HZ250479 2016-05-03 00:15:00
# 2016-05-03 21:07:00     6253257  10508690    HZ250370 2016-05-03 21:07:00
# 2016-05-03 23:38:00     6253474  10508692    HZ250517 2016-05-03 23:38:00
#
#                                     Block  IUCR     Primary Type  \
# Date
# 2016-05-03 23:33:00       026XX W 23RD PL  0486          BATTERY
# 2016-05-03 23:30:00   073XX S HARVARD AVE  1310  CRIMINAL DAMAGE
# 2016-05-03 00:15:00       024XX W 63RD ST  041A          BATTERY
# 2016-05-03 21:07:00  082XX S EXCHANGE AVE  0486          BATTERY
# 2016-05-03 23:38:00       001XX E 75TH ST  5007    OTHER OFFENSE
#
#                                  Description            Location Description  \
# Date
# 2016-05-03 23:33:00  DOMESTIC BATTERY SIMPLE                       APARTMENT
# 2016-05-03 23:30:00              TO PROPERTY                       APARTMENT
# 2016-05-03 00:15:00      AGGRAVATED: HANDGUN                        SIDEWALK
# 2016-05-03 21:07:00  DOMESTIC BATTERY SIMPLE                        SIDEWALK
# 2016-05-03 23:38:00  OTHER WEAPONS VIOLATION  PARKING LOT/GARAGE(NON.RESID.)
#
#                      Arrest  ...  Ward  Community Area  FBI Code  \
# Date                         ...
# 2016-05-03 23:33:00    True  ...  28.0            30.0       08B
# 2016-05-03 23:30:00    True  ...  17.0            69.0        14
# 2016-05-03 00:15:00   False  ...  15.0            66.0       04B
# 2016-05-03 21:07:00   False  ...   7.0            46.0       08B
# 2016-05-03 23:38:00    True  ...   6.0            69.0        26
#
#                      X Coordinate  Y Coordinate  Year              Updated On  \
# Date
# 2016-05-03 23:33:00     1159105.0     1888300.0  2016  05/10/2016 03:56:50 PM
# 2016-05-03 23:30:00     1175230.0     1856183.0  2016  05/10/2016 03:56:50 PM
# 2016-05-03 00:15:00     1161027.0     1862810.0  2016  05/10/2016 03:56:50 PM
# 2016-05-03 21:07:00     1197261.0     1850727.0  2016  05/10/2016 03:56:50 PM
# 2016-05-03 23:38:00     1178696.0     1855324.0  2016  05/10/2016 03:56:50 PM
#
#                       Latitude  Longitude                       Location
# Date
# 2016-05-03 23:33:00  41.849222 -87.691556   (41.849222028, -87.69155551)
# 2016-05-03 23:30:00  41.760744 -87.633335   (41.760743949, -87.63333531)
# 2016-05-03 00:15:00  41.779235 -87.685207  (41.779234743, -87.685207125)
# 2016-05-03 21:07:00  41.745252 -87.552773  (41.745251975, -87.552773464)
# 2016-05-03 23:38:00  41.758309 -87.620658   (41.75830866, -87.620658418)
#
# [5 rows x 23 columns]

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.year]).size().plot.line()
plt.title('Crime Over the Years')
plt.xlabel('Year')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.month]).size().plot.bar()
plt.title('Crime Per Month')
plt.xlabel('Month')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.day]).size().plot.bar()
plt.title('Crime Per Day Of Month')
plt.xlabel('Day')
plt.ylabel('No. of Crimes ')
plt.show()

# %%
plt.figure(figsize = (10,5))
data.groupby([data.index.hour]).size().plot.bar()
plt.title('Crime Per Hour')
plt.xlabel('Hour')
plt.ylabel('No. of Crimes ') 
plt.show()

# %%
crimes_count_date = data.pivot_table('ID', aggfunc=np.size, columns='Primary Type', index=data.index.date, fill_value=0)
crimes_count_date.index = pd.DatetimeIndex(crimes_count_date.index)
plo = crimes_count_date.rolling(365).sum().plot(figsize=(50, 50), subplots=True, layout=(-1, 3), sharex=False, sharey=False)
